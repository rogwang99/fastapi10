# %%
# %load_ext autoreload
# %autoreload 2

# %%
## 設定安裝目錄
from imageinit import myimage
myENV='mycolab'
resetPackage="ture"
myimage(myENV,resetPackage)
# Out:
# env: PYTHONUSERBASE=/work/c00cjz002/myenv_TMP/.package_mycolab_nchc_conda/envs/mycolab
# rm -rf /work/c00cjz002/myenv_TMP/.package_mycolab_nchc_conda

# %%
pip install -r requirements.txt
# Out:
# Collecting fastapi[all]
#   Using cached fastapi-0.70.0-py3-none-any.whl (51 kB)
# Collecting jupyterlab
#   Downloading jupyterlab-3.2.1-py3-none-any.whl (8.6 MB)
#      |████████████████████████████████| 8.6 MB 2.6 MB/s eta 0:00:01
# Collecting asyncio
#   Downloading asyncio-3.4.3-py3-none-any.whl (101 kB)
#      |████████████████████████████████| 101 kB 38.4 MB/s ta 0:00:01
# Collecting aiohttp
#   Downloading aiohttp-3.8.0-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 44.0 MB/s eta 0:00:01
# Collecting aiofiles
#   Downloading aiofiles-0.7.0-py3-none-any.whl (13 kB)
# Requirement already satisfied: pydantic!=1.7,!=1.7.1,!=1.7.2,!=1.7.3,!=1.8,!=1.8.1,<2.0.0,>=1.6.2 in /opt/conda/lib/python3.8/site-packages (from fastapi[all]->-r requirements.txt (line 1)) (1.8.2)
# Collecting starlette==0.16.0
#   Using cached starlette-0.16.0-py3-none-any.whl (61 kB)
# Requirement already satisfied: pyyaml<6.0.0,>=5.3.1; extra == "all" in /opt/conda/lib/python3.8/site-packages (from fastapi[all]->-r requirements.txt (line 1)) (5.4.1)
# Requirement already satisfied: requests<3.0.0,>=2.24.0; extra == "all" in /opt/conda/lib/python3.8/site-packages (from fastapi[all]->-r requirements.txt (line 1)) (2.24.0)
# Collecting itsdangerous<3.0.0,>=1.1.0; extra == "all"
#   Using cached itsdangerous-2.0.1-py3-none-any.whl (18 kB)
# Requirement already satisfied: jinja2<4.0.0,>=2.11.2; extra == "all" in /opt/conda/lib/python3.8/site-packages (from fastapi[all]->-r requirements.txt (line 1)) (2.11.3)
# Collecting ujson<5.0.0,>=4.0.1; extra == "all"
#   Downloading ujson-4.2.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (216 kB)
#      |████████████████████████████████| 216 kB 143.0 MB/s eta 0:00:01
# Collecting email_validator<2.0.0,>=1.1.1; extra == "all"
#   Downloading email_validator-1.1.3-py2.py3-none-any.whl (18 kB)
# Collecting uvicorn[standard]<0.16.0,>=0.12.0; extra == "all"
#   Downloading uvicorn-0.15.0-py3-none-any.whl (54 kB)
#      |████████████████████████████████| 54 kB 8.9 MB/s  eta 0:00:01
# Collecting python-multipart<0.0.6,>=0.0.5; extra == "all"
#   Downloading python-multipart-0.0.5.tar.gz (32 kB)
# Collecting orjson<4.0.0,>=3.2.1; extra == "all"
#   Downloading orjson-3.6.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (250 kB)
#      |████████████████████████████████| 250 kB 43.0 MB/s eta 0:00:01
# Collecting nbclassic~=0.2
#   Downloading nbclassic-0.3.4-py3-none-any.whl (25 kB)
# Collecting jupyterlab-server~=2.3
#   Downloading jupyterlab_server-2.8.2-py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 13.2 MB/s eta 0:00:01
# Requirement already satisfied: tornado>=6.1.0 in /opt/conda/lib/python3.8/site-packages (from jupyterlab->-r requirements.txt (line 2)) (6.1)
# Requirement already satisfied: jupyter-core in /opt/conda/lib/python3.8/site-packages (from jupyterlab->-r requirements.txt (line 2)) (4.8.1)
# Requirement already satisfied: ipython in /opt/conda/lib/python3.8/site-packages (from jupyterlab->-r requirements.txt (line 2)) (7.27.0)
# Collecting jupyter-server~=1.4
#   Downloading jupyter_server-1.11.2-py3-none-any.whl (394 kB)
#      |████████████████████████████████| 394 kB 81.3 MB/s eta 0:00:01
# Requirement already satisfied: packaging in /opt/conda/lib/python3.8/site-packages (from jupyterlab->-r requirements.txt (line 2)) (21.0)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.7.2-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (308 kB)
#      |████████████████████████████████| 308 kB 96.8 MB/s eta 0:00:01
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.8/site-packages (from aiohttp->-r requirements.txt (line 4)) (21.2.0)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.2.0-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (210 kB)
#      |████████████████████████████████| 210 kB 46.4 MB/s eta 0:00:01
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.2.0-py3-none-any.whl (8.2 kB)
# Collecting charset-normalizer<3.0,>=2.0
#   Downloading charset_normalizer-2.0.7-py3-none-any.whl (38 kB)
# Collecting multidict<7.0,>=4.5
#   Using cached multidict-5.2.0-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (187 kB)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.0-py3-none-any.whl (6.1 kB)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.8/site-packages (from pydantic!=1.7,!=1.7.1,!=1.7.2,!=1.7.3,!=1.8,!=1.8.1,<2.0.0,>=1.6.2->fastapi[all]->-r requirements.txt (line 1)) (3.7.4.3)
# Collecting anyio<4,>=3.0.0
#   Using cached anyio-3.3.4-py3-none-any.whl (78 kB)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/lib/python3.8/site-packages (from requests<3.0.0,>=2.24.0; extra == "all"->fastapi[all]->-r requirements.txt (line 1)) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.8/site-packages (from requests<3.0.0,>=2.24.0; extra == "all"->fastapi[all]->-r requirements.txt (line 1)) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.8/site-packages (from requests<3.0.0,>=2.24.0; extra == "all"->fastapi[all]->-r requirements.txt (line 1)) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/lib/python3.8/site-packages (from requests<3.0.0,>=2.24.0; extra == "all"->fastapi[all]->-r requirements.txt (line 1)) (3.0.4)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/lib/python3.8/site-packages (from jinja2<4.0.0,>=2.11.2; extra == "all"->fastapi[all]->-r requirements.txt (line 1)) (1.1.1)
# Requirement already satisfied: dnspython>=1.15.0 in /opt/conda/lib/python3.8/site-packages (from email_validator<2.0.0,>=1.1.1; extra == "all"->fastapi[all]->-r requirements.txt (line 1)) (2.1.0)
# Collecting h11>=0.8
#   Downloading h11-0.12.0-py3-none-any.whl (54 kB)
#      |████████████████████████████████| 54 kB 8.5 MB/s  eta 0:00:01
# Collecting asgiref>=3.4.0
#   Downloading asgiref-3.4.1-py3-none-any.whl (25 kB)
# Requirement already satisfied: click>=7.0 in /opt/conda/lib/python3.8/site-packages (from uvicorn[standard]<0.16.0,>=0.12.0; extra == "all"->fastapi[all]->-r requirements.txt (line 1)) (7.1.2)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0; (sys_platform != "win32" and (sys_platform != "cygwin" and platform_python_implementation != "PyPy")) and extra == "standard"
#   Downloading uvloop-0.16.0-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (4.7 MB)
#      |████████████████████████████████| 4.7 MB 23.7 MB/s eta 0:00:01�███████████████████▎         | 3.3 MB 23.7 MB/s eta 0:00:01
# Collecting watchgod>=0.6; extra == "standard"
#   Downloading watchgod-0.7-py3-none-any.whl (11 kB)
# Collecting python-dotenv>=0.13; extra == "standard"
#   Downloading python_dotenv-0.19.1-py2.py3-none-any.whl (17 kB)
# Collecting httptools==0.2.*; extra == "standard"
#   Downloading httptools-0.2.0-cp38-cp38-manylinux1_x86_64.whl (354 kB)
#      |████████████████████████████████| 354 kB 47.1 MB/s eta 0:00:01
# Collecting websockets>=9.1; extra == "standard"
#   Downloading websockets-10.0-cp38-cp38-manylinux2010_x86_64.whl (107 kB)
#      |████████████████████████████████| 107 kB 47.9 MB/s eta 0:00:01
# Requirement already satisfied: six>=1.4.0 in /opt/conda/lib/python3.8/site-packages (from python-multipart<0.0.6,>=0.0.5; extra == "all"->fastapi[all]->-r requirements.txt (line 1)) (1.15.0)
# Requirement already satisfied: notebook<7 in /opt/conda/lib/python3.8/site-packages (from nbclassic~=0.2->jupyterlab->-r requirements.txt (line 2)) (6.4.4)
# Collecting babel
#   Downloading Babel-2.9.1-py2.py3-none-any.whl (8.8 MB)
#      |████████████████████████████████| 8.8 MB 68.9 MB/s eta 0:00:010:01
# Requirement already satisfied: entrypoints>=0.2.2 in /opt/conda/lib/python3.8/site-packages (from jupyterlab-server~=2.3->jupyterlab->-r requirements.txt (line 2)) (0.3)
# Requirement already satisfied: jsonschema>=3.0.1 in /opt/conda/lib/python3.8/site-packages (from jupyterlab-server~=2.3->jupyterlab->-r requirements.txt (line 2)) (3.2.0)
# Collecting json5
#   Downloading json5-0.9.6-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: traitlets in /opt/conda/lib/python3.8/site-packages (from jupyter-core->jupyterlab->-r requirements.txt (line 2)) (5.0.5)
# Requirement already satisfied: pexpect>4.3; sys_platform != "win32" in /opt/conda/lib/python3.8/site-packages (from ipython->jupyterlab->-r requirements.txt (line 2)) (4.8.0)
# Requirement already satisfied: setuptools>=18.5 in /opt/conda/lib/python3.8/site-packages (from ipython->jupyterlab->-r requirements.txt (line 2)) (50.3.1.post20201107)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.8/site-packages (from ipython->jupyterlab->-r requirements.txt (line 2)) (4.4.2)
# Requirement already satisfied: pickleshare in /opt/conda/lib/python3.8/site-packages (from ipython->jupyterlab->-r requirements.txt (line 2)) (0.7.5)
# Requirement already satisfied: matplotlib-inline in /opt/conda/lib/python3.8/site-packages (from ipython->jupyterlab->-r requirements.txt (line 2)) (0.1.3)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /opt/conda/lib/python3.8/site-packages (from ipython->jupyterlab->-r requirements.txt (line 2)) (3.0.8)
# Requirement already satisfied: pygments in /opt/conda/lib/python3.8/site-packages (from ipython->jupyterlab->-r requirements.txt (line 2)) (2.8.0)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/lib/python3.8/site-packages (from ipython->jupyterlab->-r requirements.txt (line 2)) (0.17.0)
# Requirement already satisfied: backcall in /opt/conda/lib/python3.8/site-packages (from ipython->jupyterlab->-r requirements.txt (line 2)) (0.2.0)
# Requirement already satisfied: nbformat in /opt/conda/lib/python3.8/site-packages (from jupyter-server~=1.4->jupyterlab->-r requirements.txt (line 2)) (5.1.3)
# Requirement already satisfied: jupyter-client>=6.1.1 in /opt/conda/lib/python3.8/site-packages (from jupyter-server~=1.4->jupyterlab->-r requirements.txt (line 2)) (6.1.12)
# Requirement already satisfied: prometheus-client in /opt/conda/lib/python3.8/site-packages (from jupyter-server~=1.4->jupyterlab->-r requirements.txt (line 2)) (0.11.0)
# Requirement already satisfied: terminado>=0.8.3 in /opt/conda/lib/python3.8/site-packages (from jupyter-server~=1.4->jupyterlab->-r requirements.txt (line 2)) (0.12.1)
# Requirement already satisfied: argon2-cffi in /opt/conda/lib/python3.8/site-packages (from jupyter-server~=1.4->jupyterlab->-r requirements.txt (line 2)) (21.1.0)
# Requirement already satisfied: websocket-client in /opt/conda/lib/python3.8/site-packages (from jupyter-server~=1.4->jupyterlab->-r requirements.txt (line 2)) (1.2.1)
# Requirement already satisfied: ipython-genutils in /opt/conda/lib/python3.8/site-packages (from jupyter-server~=1.4->jupyterlab->-r requirements.txt (line 2)) (0.2.0)
# Requirement already satisfied: nbconvert in /opt/conda/lib/python3.8/site-packages (from jupyter-server~=1.4->jupyterlab->-r requirements.txt (line 2)) (5.6.1)
# Requirement already satisfied: Send2Trash in /opt/conda/lib/python3.8/site-packages (from jupyter-server~=1.4->jupyterlab->-r requirements.txt (line 2)) (1.8.0)
# Requirement already satisfied: pyzmq>=17 in /opt/conda/lib/python3.8/site-packages (from jupyter-server~=1.4->jupyterlab->-r requirements.txt (line 2)) (22.3.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/conda/lib/python3.8/site-packages (from packaging->jupyterlab->-r requirements.txt (line 2)) (2.4.7)
# Collecting sniffio>=1.1
#   Using cached sniffio-1.2.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: ipykernel in /opt/conda/lib/python3.8/site-packages (from notebook<7->nbclassic~=0.2->jupyterlab->-r requirements.txt (line 2)) (6.4.1)
# Requirement already satisfied: pytz>=2015.7 in /opt/conda/lib/python3.8/site-packages (from babel->jupyterlab-server~=2.3->jupyterlab->-r requirements.txt (line 2)) (2021.1)
# Requirement already satisfied: pyrsistent>=0.14.0 in /opt/conda/lib/python3.8/site-packages (from jsonschema>=3.0.1->jupyterlab-server~=2.3->jupyterlab->-r requirements.txt (line 2)) (0.18.0)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/lib/python3.8/site-packages (from pexpect>4.3; sys_platform != "win32"->ipython->jupyterlab->-r requirements.txt (line 2)) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->jupyterlab->-r requirements.txt (line 2)) (0.2.5)
# Requirement already satisfied: parso>=0.7.0 in /opt/conda/lib/python3.8/site-packages (from jedi>=0.16->ipython->jupyterlab->-r requirements.txt (line 2)) (0.8.1)
# Requirement already satisfied: python-dateutil>=2.1 in /opt/conda/lib/python3.8/site-packages (from jupyter-client>=6.1.1->jupyter-server~=1.4->jupyterlab->-r requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: cffi>=1.0.0 in /opt/conda/lib/python3.8/site-packages (from argon2-cffi->jupyter-server~=1.4->jupyterlab->-r requirements.txt (line 2)) (1.14.3)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/conda/lib/python3.8/site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab->-r requirements.txt (line 2)) (1.5.0)
# Requirement already satisfied: defusedxml in /opt/conda/lib/python3.8/site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab->-r requirements.txt (line 2)) (0.7.1)
# Requirement already satisfied: testpath in /opt/conda/lib/python3.8/site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab->-r requirements.txt (line 2)) (0.5.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /opt/conda/lib/python3.8/site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab->-r requirements.txt (line 2)) (0.8.4)
# Requirement already satisfied: bleach in /opt/conda/lib/python3.8/site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab->-r requirements.txt (line 2)) (4.1.0)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /opt/conda/lib/python3.8/site-packages (from ipykernel->notebook<7->nbclassic~=0.2->jupyterlab->-r requirements.txt (line 2)) (1.4.3)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.8/site-packages (from cffi>=1.0.0->argon2-cffi->jupyter-server~=1.4->jupyterlab->-r requirements.txt (line 2)) (2.20)
# Requirement already satisfied: webencodings in /opt/conda/lib/python3.8/site-packages (from bleach->nbconvert->jupyter-server~=1.4->jupyterlab->-r requirements.txt (line 2)) (0.5.1)
# Building wheels for collected packages: python-multipart
#   Building wheel for python-multipart (setup.py) ... done
#   Created wheel for python-multipart: filename=python_multipart-0.0.5-py3-none-any.whl size=31670 sha256=7d3d01c8f0999016f09939cc7ac958d3b344bf3d115e85879fff41f00bbd40d9
#   Stored in directory: /tmp/user-pip/wheels/9e/fc/1c/cf980e6413d3ee8e70cd8f39e2366b0f487e3e221aeb452eb0
# Successfully built python-multipart
# Installing collected packages: sniffio, anyio, starlette, itsdangerous, ujson, email-validator, h11, asgiref, uvloop, watchgod, python-dotenv, httptools, websockets, uvicorn, python-multipart, orjson, fastapi, jupyter-server, nbclassic, babel, json5, jupyterlab-server, jupyterlab, asyncio, multidict, yarl, frozenlist, aiosignal, charset-normalizer, async-timeout, aiohttp, aiofiles
# Successfully installed aiofiles-0.7.0 aiohttp-3.8.0 aiosignal-1.2.0 anyio-3.3.4 asgiref-3.4.1 async-timeout-4.0.0 asyncio-3.4.3 babel-2.9.1 charset-normalizer-2.0.7 email-validator-1.1.3 fastapi-0.70.0 frozenlist-1.2.0 h11-0.12.0 httptools-0.2.0 itsdangerous-2.0.1 json5-0.9.6 jupyter-server-1.11.2 jupyterlab-3.2.1 jupyterlab-server-2.8.2 multidict-5.2.0 nbclassic-0.3.4 orjson-3.6.4 python-dotenv-0.19.1 python-multipart-0.0.5 sniffio-1.2.0 starlette-0.16.0 ujson-4.2.0 uvicorn-0.15.0 uvloop-0.16.0 watchgod-0.7 websockets-10.0 yarl-1.7.2
# Note: you may need to restart the kernel to use updated packages.

# %%
# !python app/server.py
# Out:
# INFO:     Started server process [91227]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://0.0.0.0:9010 (Press CTRL+C to quit)
# WARNING:  Invalid HTTP request received.
# Traceback (most recent call last):
#   File "/work/c00cjz002/myenv_TMP/.package_mycolab_nchc_conda/envs/mycolab/lib/python3.8/site-packages/uvicorn/protocols/http/httptools_impl.py", line 131, in data_received
#     self.parser.feed_data(data)
#   File "httptools/parser/parser.pyx", line 212, in httptools.parser.parser.HttpParser.feed_data
# httptools.parser.errors.HttpParserInvalidMethodError: Invalid method encountered
# WARNING:  Invalid HTTP request received.
# Traceback (most recent call last):
#   File "/work/c00cjz002/myenv_TMP/.package_mycolab_nchc_conda/envs/mycolab/lib/python3.8/site-packages/uvicorn/protocols/http/httptools_impl.py", line 131, in data_received
#     self.parser.feed_data(data)
#   File "httptools/parser/parser.pyx", line 212, in httptools.parser.parser.HttpParser.feed_data
# httptools.parser.errors.HttpParserInvalidMethodError: Invalid method encountered
# WARNING:  Invalid HTTP request received.
# Traceback (most recent call last):
#   File "/work/c00cjz002/myenv_TMP/.package_mycolab_nchc_conda/envs/mycolab/lib/python3.8/site-packages/uvicorn/protocols/http/httptools_impl.py", line 131, in data_received
#     self.parser.feed_data(data)
#   File "httptools/parser/parser.pyx", line 212, in httptools.parser.parser.HttpParser.feed_data
# httptools.parser.errors.HttpParserInvalidMethodError: Invalid method encountered
# WARNING:  Invalid HTTP request received.
# Traceback (most recent call last):
#   File "/work/c00cjz002/myenv_TMP/.package_mycolab_nchc_conda/envs/mycolab/lib/python3.8/site-packages/uvicorn/protocols/http/httptools_impl.py", line 131, in data_received
#     self.parser.feed_data(data)
#   File "httptools/parser/parser.pyx", line 212, in httptools.parser.parser.HttpParser.feed_data
# httptools.parser.errors.HttpParserInvalidMethodError: Invalid method encountered
# WARNING:  Invalid HTTP request received.
# Traceback (most recent call last):
#   File "/work/c00cjz002/myenv_TMP/.package_mycolab_nchc_conda/envs/mycolab/lib/python3.8/site-packages/uvicorn/protocols/http/httptools_impl.py", line 131, in data_received
#     self.parser.feed_data(data)
#   File "httptools/parser/parser.pyx", line 212, in httptools.parser.parser.HttpParser.feed_data
# httptools.parser.errors.HttpParserInvalidMethodError: Invalid method encountered
# WARNING:  Invalid HTTP request received.
# Traceback (most recent call last):
#   File "/work/c00cjz002/myenv_TMP/.package_mycolab_nchc_conda/envs/mycolab/lib/python3.8/site-packages/uvicorn/protocols/http/httptools_impl.py", line 131, in data_received
#     self.parser.feed_data(data)
#   File "httptools/parser/parser.pyx", line 212, in httptools.parser.parser.HttpParser.feed_data
# httptools.parser.errors.HttpParserInvalidMethodError: Invalid method encountered
# WARNING:  Invalid HTTP request received.
# Traceback (most recent call last):
#   File "/work/c00cjz002/myenv_TMP/.package_mycolab_nchc_conda/envs/mycolab/lib/python3.8/site-packages/uvicorn/protocols/http/httptools_impl.py", line 131, in data_received
#     self.parser.feed_data(data)
#   File "httptools/parser/parser.pyx", line 212, in httptools.parser.parser.HttpParser.feed_data
# httptools.parser.errors.HttpParserInvalidMethodError: Invalid method encountered
# WARNING:  Invalid HTTP request received.
# Traceback (most recent call last):
#   File "/work/c00cjz002/myenv_TMP/.package_mycolab_nchc_conda/envs/mycolab/lib/python3.8/site-packages/uvicorn/protocols/http/httptools_impl.py", line 131, in data_received
#     self.parser.feed_data(data)
#   File "httptools/parser/parser.pyx", line 212, in httptools.parser.parser.HttpParser.feed_data
# httptools.parser.errors.HttpParserInvalidMethodError: Invalid method encountered
# INFO:     127.0.0.1:38738 - "GET /lab HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:38738 - "GET /favicon.ico HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:38738 - "GET / HTTP/1.1" 200 OK
# INFO:     127.0.0.1:38736 - "GET /static/client.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:38738 - "GET /static/style.css HTTP/1.1" 200 OK
# INFO:     127.0.0.1:41492 - "POST /analyze HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49818 - "POST /analyze HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52710 - "POST /analyze HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52760 - "GET / HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52760 - "GET /static/style.css HTTP/1.1" 304 Not Modified
# INFO:     127.0.0.1:52762 - "GET /static/client.js HTTP/1.1" 304 Not Modified
# INFO:     127.0.0.1:57138 - "GET / HTTP/1.1" 200 OK
# INFO:     127.0.0.1:57140 - "POST /analyze HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49816 - "POST /analyze HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49816 - "GET / HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49816 - "GET /static/style.css HTTP/1.1" 304 Not Modified
# INFO:     127.0.0.1:51580 - "GET /static/client.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53348 - "POST /analyze HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52022 - "GET / HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52018 - "GET /static/client.js HTTP/1.1" 304 Not Modified
# INFO:     127.0.0.1:52022 - "GET /static/style.css HTTP/1.1" 304 Not Modified
# INFO:     127.0.0.1:52022 - "GET / HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52016 - "POST /analyze HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52016 - "GET / HTTP/1.1" 200 OK
# INFO:     127.0.0.1:56936 - "GET / HTTP/1.1" 200 OK
# INFO:     127.0.0.1:56936 - "GET /static/client.js HTTP/1.1" 304 Not Modified
# INFO:     127.0.0.1:33610 - "GET / HTTP/1.1" 200 OK
# INFO:     127.0.0.1:33610 - "GET /static/client.js HTTP/1.1" 304 Not Modified
# INFO:     127.0.0.1:33610 - "GET / HTTP/1.1" 200 OK
# INFO:     127.0.0.1:33610 - "GET /static/client.js HTTP/1.1" 304 Not Modified
# INFO:     127.0.0.1:33610 - "GET / HTTP/1.1" 200 OK
# INFO:     127.0.0.1:33610 - "GET /static/client.js HTTP/1.1" 304 Not Modified
# INFO:     127.0.0.1:33610 - "GET / HTTP/1.1" 200 OK
# INFO:     127.0.0.1:33610 - "GET /static/client.js HTTP/1.1" 304 Not Modified
# INFO:     127.0.0.1:33610 - "GET / HTTP/1.1" 200 OK
# INFO:     127.0.0.1:33610 - "GET /static/client.js HTTP/1.1" 304 Not Modified
# INFO:     127.0.0.1:33610 - "GET / HTTP/1.1" 200 OK
# INFO:     127.0.0.1:33610 - "GET /static/client.js HTTP/1.1" 304 Not Modified
# INFO:     127.0.0.1:42218 - "GET / HTTP/1.1" 200 OK
# INFO:     127.0.0.1:42218 - "GET /static/client.js HTTP/1.1" 304 Not Modified
# INFO:     127.0.0.1:42218 - "GET / HTTP/1.1" 200 OK
# INFO:     127.0.0.1:42218 - "GET / HTTP/1.1" 200 OK
# INFO:     127.0.0.1:42218 - "GET / HTTP/1.1" 200 OK
# INFO:     127.0.0.1:42218 - "GET / HTTP/1.1" 200 OK
# INFO:     127.0.0.1:42218 - "GET / HTTP/1.1" 200 OK
# INFO:     127.0.0.1:42218 - "GET /static/style.css HTTP/1.1" 304 Not Modified
# INFO:     127.0.0.1:42218 - "GET / HTTP/1.1" 200 OK
# INFO:     127.0.0.1:42218 - "GET / HTTP/1.1" 200 OK
# INFO:     127.0.0.1:42218 - "GET / HTTP/1.1" 200 OK
# INFO:     127.0.0.1:47628 - "GET / HTTP/1.1" 200 OK
# INFO:     127.0.0.1:47628 - "GET / HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49354 - "GET / HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49354 - "GET /static/client.js HTTP/1.1" 304 Not Modified
# INFO:     127.0.0.1:49354 - "GET / HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49354 - "GET / HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49354 - "GET / HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49354 - "GET / HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49354 - "GET / HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49354 - "GET / HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54630 - "GET / HTTP/1.1" 200 OK
# INFO:     127.0.0.1:58532 - "GET / HTTP/1.1" 200 OK
# INFO:     127.0.0.1:58532 - "GET /static/client.js HTTP/1.1" 304 Not Modified
# INFO:     127.0.0.1:58532 - "GET / HTTP/1.1" 200 OK
# INFO:     127.0.0.1:58532 - "GET /static/client.js HTTP/1.1" 304 Not Modified
# INFO:     127.0.0.1:58532 - "GET / HTTP/1.1" 200 OK
# INFO:     127.0.0.1:58532 - "GET /static/client.js HTTP/1.1" 304 Not Modified
# INFO:     127.0.0.1:58532 - "GET / HTTP/1.1" 200 OK
# INFO:     127.0.0.1:58532 - "GET /static/client.js HTTP/1.1" 304 Not Modified
# INFO:     127.0.0.1:39862 - "POST /analyze HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53296 - "GET / HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53294 - "GET /static/client.js HTTP/1.1" 304 Not Modified
# INFO:     127.0.0.1:53296 - "GET /static/style.css HTTP/1.1" 304 Not Modified
# INFO:     127.0.0.1:53296 - "GET / HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53296 - "GET / HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53296 - "GET / HTTP/1.1" 200 OK
# INFO:     127.0.0.1:63362 - "GET / HTTP/1.1" 200 OK
# INFO:     127.0.0.1:63362 - "GET / HTTP/1.1" 200 OK
# INFO:     127.0.0.1:63358 - "GET / HTTP/1.1" 200 OK
# INFO:     127.0.0.1:63358 - "GET /static/client.js HTTP/1.1" 304 Not Modified
# INFO:     127.0.0.1:63358 - "GET / HTTP/1.1" 200 OK
# INFO:     127.0.0.1:63358 - "GET / HTTP/1.1" 200 OK
# INFO:     127.0.0.1:63358 - "GET / HTTP/1.1" 200 OK
# INFO:     127.0.0.1:63358 - "GET / HTTP/1.1" 200 OK
# INFO:     127.0.0.1:63358 - "GET /static/style.css HTTP/1.1" 200 OK
# INFO:     127.0.0.1:42866 - "GET /static/client.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:42866 - "GET /favicon.ico HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:50090 - "GET / HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50090 - "GET /static/style.css HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50112 - "GET /static/client.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50090 - "GET / HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50090 - "GET /static/style.css HTTP/1.1" 304 Not Modified
# INFO:     127.0.0.1:50090 - "GET /favicon.ico HTTP/1.1" 404 Not Found
